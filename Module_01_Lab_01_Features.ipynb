# %% [markdown]
# <a href="https://colab.research.google.com/github/MahimaRamireddy/FMML2023/blob/main/Module_01_Lab_01_Features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extracting features from data
#
# FMML Module 1, Lab 1<br>

# %%
! pip install wikipedia

import wikipedia
import nltk
from nltk.util import ngrams
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
import re
import unicodedata
import plotly.express as px
import pandas as pd
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11680 sha256=1fcfdb7c5aedc3ae36bf24058632a2f30ccc5611760ec181b83e4e06b05e8320
#   Stored in directory: /root/.cache/pip/wheels/5e/b6/c5/93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
# Successfully built wikipedia
# ...

# %% [markdown]
# # Part 1: Features of text
# How do we apply machine learning on text? We can't directly use the text as input to our algorithms. We need to convert them to features. In this notebook, we will explore a simple way of converting text to features.
#
# Let us download a few documents off Wikipedia.

# %%
topic1 = 'Giraffe'
topic2 = 'Elephant'

wikipedia.set_lang('en')

eng1 = wikipedia.page(topic1).content
eng2 = wikipedia.page(topic2).content

wikipedia.set_lang('fr')

fr1 = wikipedia.page(topic1).content
fr2 = wikipedia.page(topic2).content

# %% [markdown]
# This is what the text looks like:

# %%
fr2
# Out:
# 'Les éléphants sont des mammifères proboscidiens de la famille des Éléphantidés. Ils correspondent aujourd\'hui à trois espèces réparties en deux genres distincts. L\'éléphant de savane d\'Afrique et l\'éléphant de forêt d\'Afrique, autrefois regroupés sous la même espèce d\'« éléphant d\'Afrique », appartiennent au genre Loxodonta, tandis que l\'éléphant d\'Asie, anciennement appelé « éléphant indien », appartient au genre Elephas. Ils se différencient par certaines caractéristiques anatomiques, les éléphants d\'Asie étant en général plus petits avec des oreilles plus petites, ou encore une différence du bout de la trompe. Ces espèces survivantes font localement l\'objet de programmes ou de projets de réintroduction et de protection.\nLe mot français « éléphant » vient du mot latin elephantus qui tire son origine du grec ἐλέφας / eléphas, « ivoire » ou « éléphant ».\nL\'éléphant apparait dans de nombreuses cultures. Il est symbole de sagesse dans la culture asiatique, connu pour sa 
# ...

# %% [markdown]
# We need to clean this up a bit. Let us remove all the special characters and keep only 26 letters and space. Note that this will remove accented characters in French also. We are also removing all the numbers and spaces. So this is not an ideal solution.

# %%
def cleanup(text):
  text = text.lower()  # make it lowercase
  text = re.sub('[^a-z]+', '', text) # only keep characters
  return text

# %%
eng1 = cleanup(eng1)
eng2 = cleanup(eng2)
fr1 = cleanup(fr1)
fr2 = cleanup(fr2)

# %%
print(eng1)
# Out:
# ...

# %% [markdown]
# Now let us calculate the frequency of the character n-grams. N-grams are groups of characters of size n. A unigram is a single character and a bigram is a group of two characters and so on.
#
# Let us count the frequency of each character in a text and plot it in a histogram.

# %%
# convert a tuple of characters to a string
def tuple2string(tup):
  st = ''
  for ii in tup:
    st = st + ii
  return st

# convert a tuple of tuples to a list of strings
def key2string(keys):
  return [tuple2string(i) for i in keys]

# plot the histogram
def plothistogram(ngram):
  keys = key2string(ngram.keys())
  values = list(ngram.values())

  # sort the keys in alphabetic order
  combined = zip(keys, values)
  zipped_sorted = sorted(combined, key=lambda x: x[0])
  keys, values = map(list, zip(*zipped_sorted))
  plt.bar(keys, values)

# %% [markdown]
# Let us compare the histograms of English pages and French pages. Can you spot a difference?

# %%
unigram_eng1 = Counter(ngrams(eng1,1))
plothistogram(unigram_eng1)
plt.title('English 1')
plt.show()
unigram_eng2 = Counter(ngrams(eng2,1))
plothistogram(unigram_eng2)
plt.title('English 2')
plt.show()

# %%
unigram_fr1 = Counter(ngrams(fr1,1))
plothistogram(unigram_eng1)
plt.title('French 1')
plt.show()
unigram_fr2 = Counter(ngrams(fr2,1))
plothistogram(unigram_fr2)
plt.title('French 2')
plt.show()

# %% [markdown]
# We can see that the unigrams for French and English are very similar. So this is not a good feature if we want to distinguish between English and French. Let us look at bigrams.

# %%
bigram_eng1 = Counter(ngrams(eng1,2)) # bigrams
plothistogram(bigram_eng1)
plt.title('English 1')
plt.show()

bigram_eng2 = Counter(ngrams(eng2,2))
plothistogram(bigram_eng2)
plt.title('English 2')
plt.show()

bigram_fr1 = Counter(ngrams(fr1,2))
plothistogram(bigram_eng1)
plt.title('French 1')
plt.show()

bigram_fr2 = Counter(ngrams(fr2,2))
plothistogram(bigram_fr2)
plt.title('French 2')
plt.show()

# %% [markdown]
# Another way to visualize bigrams is to use a 2-dimensional graph.

# %%
def plotbihistogram(ngram):
  freq = np.zeros((26,26))
  for ii in range(26):
    for jj in range(26):
      freq[ii,jj] = ngram[(chr(ord('a')+ii), chr(ord('a')+jj))]
  plt.imshow(freq, cmap = 'jet')
  return freq

# %%
bieng1 = plotbihistogram(bigram_eng1)
plt.show()
bieng2 = plotbihistogram(bigram_eng2)

# %%
bifr1 = plotbihistogram(bigram_fr1)
plt.show()
bifr2 = plotbihistogram(bigram_fr2)

# %% [markdown]
# Let us look at the top 10 ngrams for each text.

# %%
from IPython.core.debugger import set_trace

def ind2tup(ind):
  ind = int(ind)
  i = int(ind/26)
  j = int(ind%26)
  return (chr(ord('a')+i), chr(ord('a')+j))

def ShowTopN(bifreq, n=10):
  f = bifreq.flatten()
  arg = np.argsort(-f)
  for ii in range(n):
    print(f'{ind2tup(arg[ii])} : {f[arg[ii]]}')

# %%
print('\nEnglish 1:')
ShowTopN(bieng1)
print('\nEnglish 2:')
ShowTopN(bieng2)
print('\nFrench 1:')
ShowTopN(bifr1)
print('\nFrench 2:')
ShowTopN(bifr2)
# Out:
# English 1:
# ('t', 'h') : 842.0
# ('h', 'e') : 697.0
# ('e', 's') : 665.0
# ('i', 'n') : 594.0
# ('a', 'n') : 538.0
# ('e', 'r') : 478.0
# ('r', 'e') : 454.0
# ('r', 'a') : 441.0
# ('a', 'l') : 404.0
# ('n', 'd') : 393.0
#
# English 2:
# ('t', 'h') : 1236.0
# ('a', 'n') : 1123.0
# ('h', 'e') : 981.0
# ('i', 'n') : 863.0
# ('n', 't') : 664.0
# ('e', 'r') : 653.0
# ('e', 's') : 637.0
# ('r', 'e') : 629.0
# ('h', 'a') : 618.0
# ('l', 'e') : 597.0
#
# French 1:
# ('e', 's') : 735.0
# ('l', 'e') : 438.0
# ('e', 'n') : 409.0
# ('d', 'e') : 390.0
# ('o', 'n') : 349.0
# ('n', 't') : 329.0
# ('r', 'e') : 315.0
# ('e', 'l') : 308.0
# ('s', 'e') : 254.0
# ('l', 'a') : 254.0
#
# French 2:
# ('e', 's') : 1075.0
# ('n', 't') : 820.0
# ('e', 'n') : 678.0
# ('d', 'e') : 675.0
# ('l', 'e') : 635.0
# ('a', 'n') : 566.0
# ('o', 'n') : 492.0
# ('r', 'e') : 486.0
# ('e', 'l') : 451.0
# ('s', 'e') : 407.0

# %% [markdown]
# We observe that the bigrams are similar across different topics but different across languages. Thus, the bigram frequency is a good feature for distinguishing languages, but not for distinguishing topics.
#
# Thus, we were able to convert a many-dimensional input (the text) to 26 dimesions (unigrams) or 26*26 dimensions (bigrams).
#
#
# A few ways to explore:
# 1. Try with different languages.
# 2. The topics we used are quite similar, wikipedia articles of 'elephant' and 'giraffe'. What happens if we use very different topics? What if we use text from another source than Wikipedia?
# 3. How can we use and visualize trigrams and higher n-grams?

# %%
pip install wikipedia
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11678 sha256=0efcabf6447d4262fecee4d69610413e2bfc4f10cad9c0119ab02565cf6f6639
#   Stored in directory: /root/.cache/pip/wheels/5e/b6/c5/93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
# Successfully built wikipedia
# ...

# %%
#1 different languages

topic1='jirafa' #giraffe in spanish
topic2='elefante'#elephant in spanish and portugese
topic3="girafa" #girafee in portugese

wikipedia.set_lang('pt') #portugese
pt1=wikipedia.page(topic3).content
pt2=wikipedia.page(topic2).content
#print(eng1)
#print(eng2)


wikipedia.set_lang('es') #spanish
es1=wikipedia.page(topic1).content
es2=wikipedia.page(topic2).content
#print(fr1)
#print(fr2)

pt1=cleanup(pt1)
pt2=cleanup(pt2)
es1=cleanup(es1)
es2=cleanup(es2)

#print(fr1)

unigram_pt1=Counter(ngrams(pt1,1))
plothistogram(unigram_pt1)
plt.title('Portugese1_unigram')
plt.show()

unigram_pt2=Counter(ngrams(pt2,1))
plothistogram(unigram_pt2)
plt.title('Portugese2_unigram')
plt.show()

unigram_es1=Counter(ngrams(es1,1))
plothistogram(unigram_es1)
plt.title('Spanish1_unigram')
plt.show()

unigram_es2=Counter(ngrams(es2,1))
plothistogram(unigram_es2)
plt.title('Spanish2_unigram')
plt.show()

bigram_pt1=Counter(ngrams(pt1,2))
plothistogram(bigram_pt1)
plt.title('Portugese1_bigram')
plt.show()

bigram_pt2=Counter(ngrams(pt2,2))
plothistogram(bigram_pt2)
plt.title('Portugese2_bigram')
plt.show()

bigram_es1=Counter(ngrams(es1,2))
plothistogram(bigram_es1)
plt.title('Spanish1_bigram')
plt.show()

bigram_es2=Counter(ngrams(es2,2))
plothistogram(bigram_es2)
plt.title('Spanish2_bigram')
plt.show()

bipt1 = plotbihistogram(bigram_pt1)
plt.title('Portugese1_bigram')
plt.show()
bipt2 = plotbihistogram(bigram_pt2)
plt.title('Portugese2_bigram')
plt.show()

bies1 = plotbihistogram(bigram_es1)
plt.title('Spanish1_bigram')
plt.show()
bies2 = plotbihistogram(bigram_es2)
plt.title('Spanish2_bigram')
plt.show()

print('\nPortugese 1:')
ShowTopN(bipt1)
print('\nPortugese 2:')
ShowTopN(bipt2)
print('\nSpanish 1:')
ShowTopN(bies1)
print('\nSpanish 2:')
ShowTopN(bies2)
# Out:
# Portugese 1:
# ('a', 's') : 186.0
# ('r', 'a') : 153.0
# ('e', 's') : 132.0
# ('o', 's') : 130.0
# ('d', 'e') : 106.0
# ('a', 'd') : 99.0
# ('a', 'n') : 99.0
# ('s', 'e') : 98.0
# ('d', 'o') : 95.0
# ('r', 'e') : 89.0
#
# Portugese 2:
# ('e', 's') : 410.0
# ('o', 's') : 364.0
# ('t', 'e') : 357.0
# ('n', 't') : 354.0
# ('a', 'n') : 348.0
# ('a', 's') : 329.0
# ('d', 'e') : 322.0
# ('s', 'e') : 245.0
# ('r', 'a') : 245.0
# ('r', 'e') : 244.0
#
# Spanish 1:
# ('e', 'n') : 895.0
# ('d', 'e') : 793.0
# ('e', 's') : 788.0
# ('a', 's') : 750.0
# ('l', 'a') : 711.0
# ('r', 'a') : 707.0
# ('o', 's') : 690.0
# ('e', 'l') : 684.0
# ('e', 'r') : 507.0
# ('a', 'r') : 483.0
#
# Spanish 2:
# ('e', 's') : 302.0
# ('e', 'l') : 260.0
# ('e', 'n') : 255.0
# ('o', 's') : 242.0
# ('d', 'e') : 225.0
# ('a', 'n') : 211.0
# ('n', 't') : 204.0
# ('l', 'e') : 192.0
# ('s', 'e') : 185.0
# ('t', 'e') : 177.0

# %%
#2 very different topics

topic1='Artifical intelligence'
topic2='Elephant'
topic3='Intelligence artificielle'


wikipedia.set_lang('en')
eng1=wikipedia.page(topic1).content
eng2=wikipedia.page(topic2).content
#print(eng1)
#print(eng2)


wikipedia.set_lang('fr')
fr1=wikipedia.page(topic3).content
fr2=wikipedia.page(topic2).content
#print(fr1)
#print(fr2)

eng1=cleanup(eng1)
eng2=cleanup(eng2)
fr1=cleanup(fr1)
fr2=cleanup(fr2)

#print(fr1)

unigram_eng1=Counter(ngrams(eng1,1))
plothistogram(unigram_eng1)
plt.title('English1_unigram')
plt.show()

unigram_eng2=Counter(ngrams(eng2,1))
plothistogram(unigram_eng2)
plt.title('Ensglish2_unigram')
plt.show()

unigram_fr1=Counter(ngrams(fr1,1))
plothistogram(unigram_fr1)
plt.title('French1_unigram')
plt.show()

unigram_fr2=Counter(ngrams(fr2,1))
plothistogram(unigram_fr2)
plt.title('French2_unigram')
plt.show()

bigram_eng1=Counter(ngrams(eng1,2))
plothistogram(bigram_eng1)
plt.title('English1_bigram')
plt.show()

bigram_eng2=Counter(ngrams(eng2,2))
plothistogram(bigram_eng2)
plt.title('English2_bigram')
plt.show()

bigram_fr1=Counter(ngrams(fr1,2))
plothistogram(bigram_fr1)
plt.title('French1_bigram')
plt.show()

bigram_fr2=Counter(ngrams(fr2,2))
plothistogram(bigram_fr2)
plt.title('French2_bigram')
plt.show()

bieng1 = plotbihistogram(bigram_eng1)
plt.title('English1_bigram')
plt.show()
bieng2 = plotbihistogram(bigram_eng2)
plt.title('English2_bigram')
plt.show()

bifr1 = plotbihistogram(bigram_fr1)
plt.title('French1_bigram')
plt.show()
bifr2 = plotbihistogram(bigram_fr2)
plt.title('French2_bigram')
plt.show()

print('\nEnglish 1:')
ShowTopN(bieng1)
print('\nEnglish 2:')
ShowTopN(bieng2)
print('\nFrench 1:')
ShowTopN(bifr1)
print('\nFrench 2:')
ShowTopN(bifr2)
# Out:
# English 1:
# ('i', 'n') : 1034.0
# ('t', 'h') : 978.0
# ('h', 'e') : 720.0
# ('a', 'n') : 692.0
# ('e', 'r') : 682.0
# ('t', 'i') : 659.0
# ('r', 'e') : 644.0
# ('e', 's') : 643.0
# ('a', 't') : 584.0
# ('o', 'n') : 575.0
#
# English 2:
# ('t', 'h') : 1236.0
# ('a', 'n') : 1123.0
# ('h', 'e') : 981.0
# ('i', 'n') : 863.0
# ('n', 't') : 664.0
# ('e', 'r') : 653.0
# ('e', 's') : 637.0
# ('r', 'e') : 629.0
# ('h', 'a') : 618.0
# ('l', 'e') : 597.0
#
# French 1:
# ('e', 's') : 2575.0
# ('e', 'n') : 1948.0
# ('l', 'e') : 1745.0
# ('d', 'e') : 1679.0
# ('n', 't') : 1663.0
# ('e', 'l') : 1642.0
# ('o', 'n') : 1546.0
# ('t', 'i') : 1397.0
# ('t', 'e') : 1348.0
# ('i', 'n') : 1182.0
#
# French 2:
# ('e', 's') : 1075.0
# ('n', 't') : 820.0
# ('e', 'n') : 678.0
# ('d', 'e') : 675.0
# ('l', 'e') : 635.0
# ('a', 'n') : 566.0
# ('o', 'n') : 492.0
# ('r', 'e') : 486.0
# ('e', 'l') : 451.0
# ('s', 'e') : 407.0

# %%
#2 different text source
import requests

topic1='https://www.ibm.com/topics/artificial-intelligence#:~:text=At%20its%20simplest%20form%2C%20artificial,in%20conjunction%20with%20artificial%20intelligence.'
topic2='https://www.britannica.com/animal/African-bush-elephant'
topic3='https://www.netapp.com/fr/artificial-intelligence/what-is-artificial-intelligence/'
topic4='https://www.cnrtl.fr/definition/%C3%A9l%C3%A9phant'

response1 = requests.get(topic1)
response2 = requests.get(topic2)
response3 = requests.get(topic3)
response4 = requests.get(topic4)

if response1.status_code == 200 and response2.status_code == 200 and response3.status_code == 200:
    eng1 = response1.text
    eng2 = response2.text
    fr1 = response3.text
    fr2 = response4.text

    eng1=cleanup(eng1)
    eng2=cleanup(eng2)
    fr1=cleanup(fr1)
    fr2=cleanup(fr2)

    #print(fr1)

    unigram_eng1=Counter(ngrams(eng1,1))
    plothistogram(unigram_eng1)
    plt.title('English1_unigram')
    plt.show()

    unigram_eng2=Counter(ngrams(eng2,1))
    plothistogram(unigram_eng2)
    plt.title('Ensglish2_unigram')
    plt.show()

    unigram_fr1=Counter(ngrams(fr1,1))
    plothistogram(unigram_fr1)
    plt.title('French1_unigram')
    plt.show()

    unigram_fr2=Counter(ngrams(fr2,1))
    plothistogram(unigram_fr2)
    plt.title('French2_unigram')
    plt.show()

    bigram_eng1=Counter(ngrams(eng1,2))
    plothistogram(bigram_eng1)
    plt.title('English1_bigram')
    plt.show()

    bigram_eng2=Counter(ngrams(eng2,2))
    plothistogram(bigram_eng2)
    plt.title('English2_bigram')
    plt.show()

    bigram_fr1=Counter(ngrams(fr1,2))
    plothistogram(bigram_fr1)
    plt.title('French1_bigram')
    plt.show()

    bigram_fr2=Counter(ngrams(fr2,2))
    plothistogram(bigram_fr2)
    plt.title('French2_bigram')
    plt.show()

    bieng1 = plotbihistogram(bigram_eng1)
    plt.title('English1_bigram')
    plt.show()
    bieng2 = plotbihistogram(bigram_eng2)
    plt.title('English2_bigram')
    plt.show()

    bifr1 = plotbihistogram(bigram_fr1)
    plt.title('French1_bigram')
    plt.show()
    bifr2 = plotbihistogram(bigram_fr2)
    plt.title('French2_bigram')
    plt.show()

    print('\nEnglish 1:')
    ShowTopN(bieng1)
    print('\nEnglish 2:')
    ShowTopN(bieng2)
    print('\nFrench 1:')
    ShowTopN(bifr1)
    print('\nFrench 2:')
    ShowTopN(bifr2)

else:
    print("Failed to fetch content from one or more URLs.")
# Out:
# English 1:
# ('n', 't') : 772.0
# ('i', 'n') : 637.0
# ('o', 'n') : 604.0
# ('t', 'e') : 581.0
# ('e', 'n') : 527.0
# ('c', 'o') : 488.0
# ('t', 'i') : 421.0
# ('e', 'r') : 386.0
# ('t', 'a') : 375.0
# ('a', 'r') : 372.0
#
# English 2:
# ('a', 'n') : 794.0
# ('o', 'n') : 786.0
# ('l', 'a') : 674.0
# ('n', 't') : 602.0
# ('s', 's') : 584.0
# ('r', 'e') : 578.0
# ('r', 'i') : 578.0
# ('t', 'a') : 575.0
# ('a', 's') : 563.0
# ('a', 'l') : 552.0
#
# French 1:
# ('l', 'i') : 614.0
# ('o', 'n') : 610.0
# ('e', 's') : 595.0
# ('t', 'i') : 590.0
# ('n', 't') : 558.0
# ('e', 'n') : 555.0
# ('t', 'e') : 530.0
# ('t', 'a') : 500.0
# ('r', 'e') : 498.0
# ('i', 'n') : 478.0
#
# French 2:
# ('a', 'n') : 799.0
# ('p', 'a') : 633.0
# ('s', 'p') : 632.0
# ('o', 'n') : 500.0
# ('t', 'i') : 482.0
# ('l', 'a') : 462.0
# ('s', 's') : 442.0
# ('s', 't') : 393.0
# ('a', 's') : 377.0
# ('c', 'l') : 370.0

# %%
# trigram

topic1='Artifical intelligence'
topic2='Elephant'
topic3='Intelligence artificielle'


wikipedia.set_lang('en')
eng1=wikipedia.page(topic1).content
eng2=wikipedia.page(topic2).content
#print(eng1)
#print(eng2)


wikipedia.set_lang('fr')
fr1=wikipedia.page(topic3).content
fr2=wikipedia.page(topic2).content
#print(fr1)
#print(fr2)

eng1=cleanup(eng1)
eng2=cleanup(eng2)
fr1=cleanup(fr1)
fr2=cleanup(fr2)

#print(fr1)

trigram_eng1=Counter(ngrams(eng1,3))
plothistogram(trigram_eng1)
plt.title('English1_trigram')
plt.show()

trigram_eng2=Counter(ngrams(eng2,3))
plothistogram(trigram_eng2)
plt.title('Ensglish2_trigram')
plt.show()

trigram_fr1=Counter(ngrams(fr1,3))
plothistogram(trigram_fr1)
plt.title('French1_trigram')
plt.show()

trigram_fr2=Counter(ngrams(fr1,3))
plothistogram(trigram_fr2)
plt.title('French1_trigram')
plt.show()

# %% [markdown]
# 3d graphs are used to visualise tri-gram. n-dimensional graph is used to visualise higher n-grams.

# %% [markdown]
# # Part 2: Written numbers
#
# We will use a subset of the MNIST dataset. Each input character is represented in a 28*28 array. Let us see if we can extract some simple features from these images which can help us distinguish between the digits.
#
# Load the dataset:

# %%
from keras.datasets import mnist

#loading the dataset
(train_X, train_y), (test_X, test_y) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# Extract a subset of the data for our experiment:

# %%
no1 = train_X[train_y==1,:,:]
no0 = train_X[train_y==0,:,:]

# %% [markdown]
# Let us visualize a few images here:

# %%
for ii in range(5):
  plt.subplot(1, 5, ii+1)
  plt.imshow(no1[ii,:,:])
plt.show()
for ii in range(5):
  plt.subplot(1, 5, ii+1)
  plt.imshow(no0[ii,:,:])
plt.show()

# %% [markdown]
# suNow, let us start with a simple feature: the sum of all pixels and see how good this feature is.

# %%
sum1 = np.sum(no1>0, (1,2)) # threshold before adding up
sum0 = np.sum(no0>0, (1,2))

# %% [markdown]
# Let us visualize how good this feature is: (X-axis is mean, y-axis is the digit)

# %%
plt.hist(sum1, alpha=0.7);
plt.hist(sum0, alpha=0.7);

# %% [markdown]
# We can already see that this feature separates the two classes quite well.
#
# Let us look at another, more complicated feature. We will count the number black pixels that are surrounded on four sides by non-black pixels, or "hole pixels".

# %%
def cumArray(img):
  img2 = img.copy()
  for ii in range(1, img2.shape[1]):
    img2[ii,:] = img2[ii,:] + img2[ii-1,:]  # for every row, add up all the rows above it.
  img2 = img2>0
  return img2

def getHolePixels(img):
  im1 = cumArray(img)
  im2 = np.rot90(cumArray(np.rot90(img)), 3) # rotate and cumulate it again for differnt direction
  im3 = np.rot90(cumArray(np.rot90(img, 2)), 2)
  im4 = np.rot90(cumArray(np.rot90(img, 3)), 1)
  hull =  im1 & im2 & im3 & im4 # this will create a binary image with all the holes filled in.
  hole = hull & ~ (img>0) # remove the original digit to leave behind the holes
  return hole

# %% [markdown]
# Visualize a few:

# %%
imgs = [no1[456,:,:],  no0[456,:,:]]
for img in imgs:
  plt.subplot(1,2,1)
  plt.imshow(getHolePixels(img))
  plt.subplot(1,2,2)
  plt.imshow(img)
  plt.show()

# %% [markdown]
# Now let us plot the number of hole pixels and see how this feature behaves

# %%
hole1 = np.array([getHolePixels(i).sum() for i in no1])
hole0 = np.array([getHolePixels(i).sum() for i in no0])

plt.hist(hole1, alpha=0.7);
plt.hist(hole0, alpha=0.7);

# %% [markdown]
# This feature works even better to distinguish between one and zero.
#
#
# Now let us try the number of pixels in the 'hull' or the number with the holes filled in:

# %%
def getHullPixels(img):
  im1 = cumArray(img)
  im2 = np.rot90(cumArray(np.rot90(img)), 3) # rotate and cumulate it again for differnt direction
  im3 = np.rot90(cumArray(np.rot90(img, 2)), 2)
  im4 = np.rot90(cumArray(np.rot90(img, 3)), 1)
  hull =  im1 & im2 & im3 & im4 # this will create a binary image with all the holes filled in.
  return hull

# %%
imgs = [no1[456,:,:],  no0[456,:,:]]
for img in imgs:
  plt.subplot(1,2,1)
  plt.imshow(getHullPixels(img))
  plt.subplot(1,2,2)
  plt.imshow(img)
  plt.show()

# %% [markdown]
# Plotting the number of hull pixels versus the digit:

# %%
hull1 = np.array([getHullPixels(i).sum() for i in no1])
hull0 = np.array([getHullPixels(i).sum() for i in no0])

plt.hist(hull1, alpha=0.7);
plt.hist(hull0, alpha=0.7);

# %% [markdown]
# Let us try one more feature, where we look at the number of boundary pixels in each image.

# %%
def minus(a, b):
  return a & ~ b

def getBoundaryPixels(img):
  img = img.copy()>0  # binarize the image
  rshift = np.roll(img, 1, 1)
  lshift = np.roll(img, -1 ,1)
  ushift = np.roll(img, -1, 0)
  dshift = np.roll(img, 1, 0)
  boundary = minus(img, rshift) | minus(img, lshift) | minus(img, ushift) | minus(img, dshift)
  return boundary

# %%
imgs = [no1[456,:,:],  no0[456,:,:]]
for img in imgs:
  plt.subplot(1,2,1)
  plt.imshow(getBoundaryPixels(img))
  plt.subplot(1,2,2)
  plt.imshow(img)
  plt.show()

# %%
bound1 = np.array([getBoundaryPixels(i).sum() for i in no1])
bound0= np.array([getBoundaryPixels(i).sum() for i in no0])

plt.hist(bound1, alpha=0.7);
plt.hist(bound0, alpha=0.7);

# %% [markdown]
# What will happen if we plot two features together?

# %%
# Sum and hull
plt.scatter(sum0, hull0, alpha=0.1)
plt.scatter(sum1, hull1, alpha=0.1)
plt.xlabel('Sum')
plt.ylabel('Hull')
plt.legend(['0','1'])
plt.show()

# Sum and hole
plt.scatter(sum0, hole0, alpha=0.1)
plt.scatter(sum1, hole1, alpha=0.1)
plt.xlabel('Sum');
plt.ylabel('Hole');
plt.legend(['0','1'])
plt.show()

# Hole and boundary
plt.scatter(bound0, hole0, alpha=0.1)
plt.scatter(bound1, hole1, alpha=0.1)
plt.xlabel('Boundary');
plt.ylabel('Hole');
plt.legend(['0','1'])
plt.show()

# %% [markdown]
# Now let us try plotting 3 features together.

# %%
cl1 = ['class 1']*len(sum1)
cl0 = ['class 0']*len(sum0)
df = pd.DataFrame(list(zip(np.concatenate((hole0, hole0)), np.concatenate((sum1,sum0)),
                           np.concatenate((bound1,bound0)), np.concatenate((cl1, cl0)))),
               columns =['Hole', 'Sum', 'Boundary', 'Class'])
df.head()
fig = px.scatter_3d(df, x='Hole', y='Sum', z='Boundary', color='Class', opacity=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Feel free to explore the above graph with your mouse.
#
#
# We have seen that we extracted four features from a 28*28 dimensional image.
#
#
# Some questions to explore:
# 1. Which is the best combination of features?
# 2. How would you test or visualize four or more features?
# 3. Can you come up with your own features?
# 4. Will these features work for different classes other than 0 and 1?
# 5. What will happen if we take more that two classes at a time?

# %% [markdown]
# 1.The "Hole and Boundary" duo-combination appears to have less overlap between the two classes compared to the other combinations. Hence it is the best combination of 2 features.

# %% [markdown]
# 3.**Area**: Calculate the area of each digit's bounding box or the number of non-zero pixels in the image.
#
# **Aspect Ratio**: Compute the ratio of the width to the height of the bounding box. Anomalies in aspect ratios may help distinguish classes.
#
# **Eccentricity**: Measure how elongated or circular the digit shape is. Eccentricity values can range from 0 (perfectly circular) to 1 (highly elongated).
#
# **Orientation**: Calculate the angle at which the major axis of the digit's bounding box is oriented.

# %% [markdown]
# 4.Yes in the above features area,eccentricity and orientation work perfectly well for other classes than 0 and 1. aspect ratio is not so perfect.
